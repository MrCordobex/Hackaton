# %% [markdown]
# # Exploración inicial
#
# Carga y vistazo rápido a los CSV en `data/raw`.

# %%
import pandas as pd, glob
files = glob.glob('../data/raw/*.csv')
files

# %%
dfs = [pd.read_csv(f) for f in files]
dfs[0].head() if dfs else 'No hay CSV'
